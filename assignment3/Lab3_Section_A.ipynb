# %%
# libraries to be imported
from pyspark.sql import SparkSession
from collections import Counter

# %%
# New API
spark_session = SparkSession\
        .builder\
        .master("spark://192.168.2.87:7077")\
        .appName("Uvais_Section_A_Session")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.shuffle.service.enabled", True)\
        .config("spark.dynamicAllocation.executorIdleTimeout","30s")\
        .config("spark.executor.cores",4)\
        .getOrCreate()
        
# Old API (RDD)
spark_context = spark_session.sparkContext

# %% [markdown]
# ### ---------------- Question A.1 -----------------

# %%
# Question A1.1
# reading English file from hadoop
rdd1 = spark_context.newAPIHadoopFile(
    'hdfs://192.168.2.87:9000/europarl/europarl-v7.sv-en.en',
    'org.apache.hadoop.mapreduce.lib.input.TextInputFormat',
    'org.apache.hadoop.io.LongWritable',
    'org.apache.hadoop.io.Text'
)

print("Example lines to check language: "+str(rdd1.take(2)))
print("Number of lines in europarl-v7.sv-en.en: "+str(rdd1.count()))
# Out:
# Example lines to check language: [(0, 'Resumption of the session'), (26, 'I declare resumed the session of the European Parliament adjourned on Friday 17 December 1999, and I would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period.')]
# Number of lines in europarl-v7.sv-en.en: 1862234

# %%
# Question A1.2
# reading Swedish file from hadoop
rdd2 = spark_context.newAPIHadoopFile(
    'hdfs://192.168.2.87:9000/europarl/europarl-v7.sv-en.sv',
    'org.apache.hadoop.mapreduce.lib.input.TextInputFormat',
    'org.apache.hadoop.io.LongWritable',
    'org.apache.hadoop.io.Text'
)

print("Example lines to check language: "+str(rdd2.take(2)))
print("Number of lines in europarl-v7.sv-en.sv: "+str(rdd2.count()))
# Out:
# Example lines to check language: [(0, 'Återupptagande av sessionen'), (29, 'Jag förklarar Europaparlamentets session återupptagen efter avbrottet den 17 december. Jag vill på nytt önska er ett gott nytt år och jag hoppas att ni haft en trevlig semester.')]
# Number of lines in europarl-v7.sv-en.sv: 1862234

# %%
# Question A.1.3
# Checking the number of lines are same
print("Check if both documents  have same number of line: "+str(rdd1.count()==rdd2.count()))
# Out:
# Check if both documents  have same number of line: True

# %%
# Question A.1.4
# Checking the number of partitions in RDD's
print("No of partions present in RDD1: "+str(rdd1.getNumPartitions()))
print("No of partions present in RDD2: "+str(rdd2.getNumPartitions()))
# Out:
# No of partions present in RDD1: 2
# No of partions present in RDD2: 3

# %% [markdown]
# ### ---------------- Question A.2 -----------------

# %%
# Question A2.1
# converting to lowercase and tokenizing
def lowerandtokenize(rdd):
    rdd_tokenized = rdd.map(lambda eachtuple: eachtuple[1].lower())\
            .map(lambda eachSentence: eachSentence.split(' '))
    return rdd_tokenized
rdd1_Tokenized = lowerandtokenize(rdd1)
rdd2_Tokenized = lowerandtokenize(rdd2)
# print the output from function
print("Sample of RDD1: "+str(rdd1_Tokenized.take(2)))
print("\nSample of RDD2: "+str(rdd2_Tokenized.take(2)))
# Out:
# Sample of RDD1: [['resumption', 'of', 'the', 'session'], ['i', 'declare', 'resumed', 'the', 'session', 'of', 'the', 'european', 'parliament', 'adjourned', 'on', 'friday', '17', 'december', '1999,', 'and', 'i', 'would', 'like', 'once', 'again', 'to', 'wish', 'you', 'a', 'happy', 'new', 'year', 'in', 'the', 'hope', 'that', 'you', 'enjoyed', 'a', 'pleasant', 'festive', 'period.']]
#
# Sample of RDD2: [['återupptagande', 'av', 'sessionen'], ['jag', 'förklarar', 'europaparlamentets', 'session', 'återupptagen', 'efter', 'avbrottet', 'den', '17', 'december.', 'jag', 'vill', 'på', 'nytt', 'önska', 'er', 'ett', 'gott', 'nytt', 'år', 'och', 'jag', 'hoppas', 'att', 'ni', 'haft', 'en', 'trevlig', 'semester.']]

# %%
# Question A2.2
# converting to lowercase and tokenizing
print("10 RDD1 Sentence After Tokenization: \n"+\
      str(rdd1_Tokenized.take(10)))
print("\n10 RDD2 Sentence After Tokenization: \n"+\
      str(rdd2_Tokenized.take(10)))
# Out:
# 10 RDD1 Sentence After Tokenization:
# [['resumption', 'of', 'the', 'session'], ['i', 'declare', 'resumed', 'the', 'session', 'of', 'the', 'european', 'parliament', 'adjourned', 'on', 'friday', '17', 'december', '1999,', 'and', 'i', 'would', 'like', 'once', 'again', 'to', 'wish', 'you', 'a', 'happy', 'new', 'year', 'in', 'the', 'hope', 'that', 'you', 'enjoyed', 'a', 'pleasant', 'festive', 'period.'], ['although,', 'as', 'you', 'will', 'have', 'seen,', 'the', 'dreaded', "'millennium", "bug'", 'failed', 'to', 'materialise,', 'still', 'the', 'people', 'in', 'a', 'number', 'of', 'countries', 'suffered', 'a', 'series', 'of', 'natural', 'disasters', 'that', 'truly', 'were', 'dreadful.'], ['you', 'have', 'requested', 'a', 'debate', 'on', 'this', 'subject', 'in', 'the', 'course', 'of', 'the', 'next', 'few', 'days,', 'during', 'this', 'part-session.'], ['in', 'the', 'meantime,', 'i', 'should', 'like', 'to', 'observe', 'a', "minute'", 's', 'silence,', 'as', 'a', 'number', 'of', 'members', 'have', 'requested,', 'on', 'behalf', 'of', 'all', 'the', 'victims', 'concerned,', 'particularly', 'those', 'of', 'the', 'terrible', 'storms,', 'in', 'the', 'various', 'countries', 'of', 'the', 'european', 'union.'], ['please', 'rise,', 'then,', 'for', 'this', "minute'", 's', 'silence.'], ['(the', 'house', 'rose', 'and', 'observed', 'a', "minute'", 's', 'silence)'], ['madam', 'president,', 'on', 'a', 'point', 'of', 'order.'], ['you', 'will', 'be', 'aware', 'from', 'the', 'press', 'and', 'television', 'that', 'there', 'have', 'been', 'a', 'number', 'of', 'bomb', 'explosions', 'and', 'killings', 'in', 'sri', 'lanka.'], ['one', 'of', 'the', 'people', 'assassinated', 'very', 'recently', 'in', 'sri', 'lanka', 'was', 'mr', 'kumar', 'ponnambalam,', 'who', 'had', 'visited', 'the', 'european', 'parliament', 'just', 'a', 'few', 'months', 'ago.']]
#
# 10 RDD2 Sentence After Tokenization:
# [['återupptagande', 'av', 'sessionen'], ['jag', 'förklarar', 'europaparlamentets', 'session', 'återupptagen', 'efter', 'avbrottet', 'den', '17', 'december.', 'jag', 'vill', 'på', 'nytt', 'önska', 'er', 'ett', 'gott', 'nytt', 'år', 'och', 'jag', 'hoppas', 'att', 'ni', 'haft', 'en', 'trevlig', 'semester.'], ['som', 'ni', 'kunnat', 'konstatera', 'ägde', '"den', 'stora', 'år', '2000-buggen"', 'aldrig', 'rum.', 'däremot', 'har', 'invånarna', 'i', 'ett', 'antal', 'av', 'våra', 'medlemsländer', 'drabbats', 'av', 'naturkatastrofer', 'som', 'verkligen', 'varit', 'förskräckliga.'], ['ni', 'har', 'begärt', 'en', 'debatt', 'i', 'ämnet', 'under', 'sammanträdesperiodens', 'kommande', 'dagar.'], ['till', 'dess', 'vill', 'jag', 'att', 'vi,', 'som', 'ett', 'antal', 'kolleger', 'begärt,', 'håller', 'en', 'tyst', 'minut', 'för', 'offren', 'för', 'bl.a.', 'stormarna', 'i', 'de', 'länder', 'i', 'europeiska', 'unionen', 'som', 'drabbats.'], ['jag', 'ber', 'er', 'resa', 'er', 'för', 'en', 'tyst', 'minut.'], ['(parlamentet', 'höll', 'en', 'tyst', 'minut.)'], ['fru', 'talman!', 'det', 'gäller', 'en', 'ordningsfråga.'], ['ni', 'känner', 'till', 'från', 'media', 'att', 'det', 'skett', 'en', 'rad', 'bombexplosioner', 'och', 'mord', 'i', 'sri', 'lanka.'], ['en', 'av', 'de', 'personer', 'som', 'mycket', 'nyligen', 'mördades', 'i', 'sri', 'lanka', 'var', 'kumar', 'ponnambalam,', 'som', 'besökte', 'europaparlamentet', 'för', 'bara', 'några', 'månader', 'sedan.']]

# %%
# Question A2.3
# counting sentence in Each RDD
print("Sentence in RDD1: "+str(rdd1_Tokenized.count()))
print("Sentence in RDD2: "+str(rdd2_Tokenized.count()))
# Out:
# Sentence in RDD1: 1862234
# Sentence in RDD2: 1862234

# %% [markdown]
# ### ---------------- Question A.3 -----------------

# %%
# Question A3.1
# 1. converting to lowercase and tokenizing to words
# 2. mapping to key, value pair
# 3. reducing to count the number of word occurance
# Finally list of no of times each word occur
# English Doc
rdd1_Word_Frequency = rdd1.map(lambda eachtuple: eachtuple[1].lower())\
        .flatMap(lambda eachSentence: (eachSentence.split(' ')))\
        .map(lambda eachWord: (eachWord,1))\
        .reduceByKey(lambda value1,value2: value1+value2)\
        .sortBy(lambda Pair: Pair[1],False)

# top 10 Frequently occuring word 
rdd1_Top_10_words = rdd1_Word_Frequency.take(10)
rdd1_Top_10_words
# Out:
# [('the', 3498375),
#  ('of', 1659758),
#  ('to', 1539760),
#  ('and', 1288401),
#  ('in', 1085993),
#  ('that', 797516),
#  ('a', 773522),
#  ('is', 758050),
#  ('for', 534242),
#  ('we', 522849)]

# %%
# Swedish Doc
rdd2_Word_Frequency = rdd2.map(lambda eachtuple: eachtuple[1].lower())\
        .flatMap(lambda eachSentence: (eachSentence.split(' ')))\
        .map(lambda eachWord: (eachWord,1))\
        .reduceByKey(lambda value1,value2: value1+value2)\
        .sortBy(lambda Pair: Pair[1],False)

# top 10 Frequently occuring word 
rdd2_Top_10_words = rdd2_Word_Frequency.take(10)
rdd2_Top_10_words
# Out:
# [('att', 1706293),
#  ('och', 1344830),
#  ('i', 1050774),
#  ('det', 924866),
#  ('som', 913276),
#  ('för', 908680),
#  ('av', 738068),
#  ('är', 694381),
#  ('en', 620310),
#  ('vi', 539797)]

# %%
# Question A.3.2
# Checking whether the above count are reasonable
print("Total no of word in RDD1: "+str(rdd1_Word_Frequency.values().sum()))
print("Average no of word in RDD1: "+str(rdd1_Word_Frequency.values().sum()/rdd1_Word_Frequency.count()))
print("\nTotal no of word in RDD2: "+str(rdd2_Word_Frequency.values().sum()))
print("Average no of word in RDD2: "+str(rdd2_Word_Frequency.values().sum()/rdd1_Word_Frequency.count()))

# the most occuring words should be verbs...
# ...like the, a, is which are always frequently...
# ...used to build sentences.
# even in my answers :)
# Out:
# Total no of word in RDD1: 45778381
# Average no of word in RDD1: 166.48802938555815
#
# Total no of word in RDD2: 41604741
# Average no of word in RDD2: 151.3092248104304

# %% [markdown]
# ### ---------------- Question A.4 -----------------

# %%
# Question A.4.1.1
# Assigning index to line list
en_1 = rdd1_Tokenized.zipWithIndex()
sv_1 = rdd2_Tokenized.zipWithIndex()

print("rdd1 after adding index: "+str(en_1.take(2)))
print("rdd2 after adding index: "+str(sv_1.take(2)))
# Out:
# rdd1 after adding index: [(['resumption', 'of', 'the', 'session'], 0), (['i', 'declare', 'resumed', 'the', 'session', 'of', 'the', 'european', 'parliament', 'adjourned', 'on', 'friday', '17', 'december', '1999,', 'and', 'i', 'would', 'like', 'once', 'again', 'to', 'wish', 'you', 'a', 'happy', 'new', 'year', 'in', 'the', 'hope', 'that', 'you', 'enjoyed', 'a', 'pleasant', 'festive', 'period.'], 1)]
# rdd2 after adding index: [(['återupptagande', 'av', 'sessionen'], 0), (['jag', 'förklarar', 'europaparlamentets', 'session', 'återupptagen', 'efter', 'avbrottet', 'den', '17', 'december.', 'jag', 'vill', 'på', 'nytt', 'önska', 'er', 'ett', 'gott', 'nytt', 'år', 'och', 'jag', 'hoppas', 'att', 'ni', 'haft', 'en', 'trevlig', 'semester.'], 1)]

# %%
# Question A.4.1.2
# Swapping Keys and Values
en_2 = en_1.map(lambda tuple1: (tuple1[1], tuple1[0]))
sv_2 = sv_1.map(lambda tuple1: (tuple1[1], tuple1[0]))

print("rdd1 after adding index: "+str(en_2.take(2)))
print("rdd2 after adding index: "+str(sv_2.take(2)))
# Out:
# rdd1 after adding index: [(0, ['resumption', 'of', 'the', 'session']), (1, ['i', 'declare', 'resumed', 'the', 'session', 'of', 'the', 'european', 'parliament', 'adjourned', 'on', 'friday', '17', 'december', '1999,', 'and', 'i', 'would', 'like', 'once', 'again', 'to', 'wish', 'you', 'a', 'happy', 'new', 'year', 'in', 'the', 'hope', 'that', 'you', 'enjoyed', 'a', 'pleasant', 'festive', 'period.'])]
# rdd2 after adding index: [(0, ['återupptagande', 'av', 'sessionen']), (1, ['jag', 'förklarar', 'europaparlamentets', 'session', 'återupptagen', 'efter', 'avbrottet', 'den', '17', 'december.', 'jag', 'vill', 'på', 'nytt', 'önska', 'er', 'ett', 'gott', 'nytt', 'år', 'och', 'jag', 'hoppas', 'att', 'ni', 'haft', 'en', 'trevlig', 'semester.'])]

# %%
# Question A.4.1.3
# Joining rdd based on key 
en_sv_3 = en_2.join(sv_2)

print("rdd after joining: "+str(en_sv_3.take(2)))
# Out:
# rdd after joining: [(83890, (['the', 'saddest', 'case', 'of', 'all', 'is', 'a', 'school', 'leaver', 'with', 'no', 'qualifications', 'to', 'his', 'credit', 'descending', 'into', 'hopelessness.'], ['det', 'sorgligaste', 'fallet', 'av', 'dem', 'alla', 'är', 'en', 'avgångselev', 'utan', 'några', 'erhållna', 'kvalifikationer', 'som', 'sjunker', 'ned', 'i', 'hopplöshet.'])), (94660, (['while', 'we', 'welcome', 'the', 'adoption', 'of', 'the', 'legislation', 'regarding', 'the', 'khmer', 'rouge', 'tribunal,', 'both', 'by', 'the', 'national', 'assembly', 'and', 'by', 'the', 'senate,', 'it', 'should', 'be', 'borne', 'in', 'mind', 'that', 'we', 'are', 'still', 'awaiting', 'the', 'official', 'statement', 'from', 'the', 'united', 'nations', 'on', 'the', 'draft', 'text.'], ['vi', 'välkomnar', 'antagandet', 'av', 'lagstiftningen', 'om', 'röda', 'khmertribunalen,', 'både', 'i', 'nationalförsamlingen', 'och', 'i', 'senaten.', 'men', 'vi', 'bör', 'komma', 'ihåg', 'att', 'vi', 'fortfarande', 'väntar', 'på', 'ett', 'officiellt', 'uttalande', 'från', 'förenta', 'nationerna', 'om', 'förslaget', 'till', 'text.']))]

# %%
# Question A.4.1.4
# Filter empty or null sentence
en_sv_4 = en_sv_3.filter(lambda x: x[1][0] is not None)\
        .filter(lambda x: x[1][1] is not None)\
        .filter(lambda x: x[1][0] is not '')\
        .filter(lambda x: x[1][1] is not '')
        
print("rdd after removing empty and null: "+str(en_sv_4.take(2)))
# Out:
# rdd after removing empty and null: [(83890, (['the', 'saddest', 'case', 'of', 'all', 'is', 'a', 'school', 'leaver', 'with', 'no', 'qualifications', 'to', 'his', 'credit', 'descending', 'into', 'hopelessness.'], ['det', 'sorgligaste', 'fallet', 'av', 'dem', 'alla', 'är', 'en', 'avgångselev', 'utan', 'några', 'erhållna', 'kvalifikationer', 'som', 'sjunker', 'ned', 'i', 'hopplöshet.'])), (94660, (['while', 'we', 'welcome', 'the', 'adoption', 'of', 'the', 'legislation', 'regarding', 'the', 'khmer', 'rouge', 'tribunal,', 'both', 'by', 'the', 'national', 'assembly', 'and', 'by', 'the', 'senate,', 'it', 'should', 'be', 'borne', 'in', 'mind', 'that', 'we', 'are', 'still', 'awaiting', 'the', 'official', 'statement', 'from', 'the', 'united', 'nations', 'on', 'the', 'draft', 'text.'], ['vi', 'välkomnar', 'antagandet', 'av', 'lagstiftningen', 'om', 'röda', 'khmertribunalen,', 'både', 'i', 'nationalförsamlingen', 'och', 'i', 'senaten.', 'men', 'vi', 'bör', 'komma', 'ihåg', 'att', 'vi', 'fortfarande', 'väntar', 'på', 'ett', 'officiellt', 'uttalande', 'från', 'förenta', 'nationerna', 'om', 'förslaget', 'till', 'text.']))]

# %%
# Question A.4.1.5
# Filter sentence with more than 10 words
en_sv_5 = en_sv_4.filter(lambda x: len(x[1][0]) < 10 and len(x[1][1]) < 10 )
print("rdd after filtering sentence with less than 6 words: "+str(en_sv_5.take(10)))
# Out:
# rdd after filtering sentence with less than 6 words: [(292930, (['my', 'next', 'question', 'concerns', 'the', 'food', 'safety', 'authority.'], ['nästa', 'fråga', 'gäller', 'myndigheten', 'för', 'livsmedelssäkerhet.'])), (402305, (['this', 'can', 'lead', 'to', 'people', 'being', 'deported.'], ['det', 'kan', 'innebära', 'att', 'folk', 'utvisas.'])), (421220, (['this', 'evidence', 'should', 'involve', 'fishermen', 'as', 'well', 'as', 'scientists.'], ['såväl', 'yrkesfiskare', 'som', 'forskare', 'bör', 'delta', 'i', 'denna', 'kartläggning.'])), (528870, (['\xa0\xa0', 'mr\xa0president,', 'there', 'is', 'some', 'confusion', 'here.'], ['\xa0\xa0', '–', 'herr', 'talman!', 'det', 'råder', 'viss', 'förvirring', 'här.'])), (69965, (['question', 'no', '33', 'by', '(h-0573/00):'], ['fråga', 'nr', '33', 'från', '(h-0573/00):'])), (389975, (['this', 'is', 'a', 'false', 'distinction.'], ['detta', 'är', 'en', 'falsk', 'skiljelinje.'])), (429180, (['clearly,', 'no', 'country', 'or', 'sector', 'is', 'risk-free.'], ['uppenbarligen', 'är', 'inget', 'land', 'eller', 'område', 'riskfritt.'])), (724035, (['secondly,', 'the', 'situation', 'calls', 'for', 'greater', 'transparency.'], ['för', 'det', 'andra', 'kräver', 'situationen', 'större', 'öppenhet.'])), (357520, (['our', 'committee', 'can', 'make', 'proposals', 'but', 'not', 'set', 'parameters.'], ['utskottet', 'kan', 'endast', 'komma', 'med', 'förslag,', 'inte', 'ge', 'instruktioner.'])), (490955, (['and', 'i', 'will', 'therefore', 'end,', 'mr', 'president', '...'], ['och', 'jag', 'kommer', 'därför', 'att', 'avsluta,', 'herr', 'talman', '...']))]

# %%
# Question A.4.1.6
# Filter sentence with equal no of words
en_sv_6 = en_sv_5.filter(lambda x: len(x[1][0]) == len(x[1][1]))
print("rdd after filtering pair wit equal no of words: "+str(en_sv_6.take(10)))
# Out:
# rdd after filtering pair wit equal no of words: [(421220, (['this', 'evidence', 'should', 'involve', 'fishermen', 'as', 'well', 'as', 'scientists.'], ['såväl', 'yrkesfiskare', 'som', 'forskare', 'bör', 'delta', 'i', 'denna', 'kartläggning.'])), (69965, (['question', 'no', '33', 'by', '(h-0573/00):'], ['fråga', 'nr', '33', 'från', '(h-0573/00):'])), (389975, (['this', 'is', 'a', 'false', 'distinction.'], ['detta', 'är', 'en', 'falsk', 'skiljelinje.'])), (429180, (['clearly,', 'no', 'country', 'or', 'sector', 'is', 'risk-free.'], ['uppenbarligen', 'är', 'inget', 'land', 'eller', 'område', 'riskfritt.'])), (724035, (['secondly,', 'the', 'situation', 'calls', 'for', 'greater', 'transparency.'], ['för', 'det', 'andra', 'kräver', 'situationen', 'större', 'öppenhet.'])), (357520, (['our', 'committee', 'can', 'make', 'proposals', 'but', 'not', 'set', 'parameters.'], ['utskottet', 'kan', 'endast', 'komma', 'med', 'förslag,', 'inte', 'ge', 'instruktioner.'])), (672750, (['we', 'have', 'no', 'alternative.'], ['vi', 'har', 'inget', 'val.'])), (188495, (['the', 'vote', 'will', 'take', 'place', 'today', 'at', '12', 'noon.'], ['omröstningen', 'kommer', 'att', 'äga', 'rum', 'i', 'dag', 'kl.', '12.00.'])), (265725, ([''], ['.'])), (395455, (['question', 'no', '50', 'by', 'alexander', 'de', 'roo', '(h-0431/03):'], ['fråga', 'nr', '50', 'från', 'alexander', 'de', 'roo', '(h-0431/03):']))]

# %%
# Question A.4.1.7
# Mapping to generate a list of translation
en_sv_7 = en_sv_6.map(lambda pair: list(zip(pair[1][0],pair[1][1])) )
en_sv_7.take(20)
# Out:
# [[('this', 'såväl'),
#   ('evidence', 'yrkesfiskare'),
#   ('should', 'som'),
#   ('involve', 'forskare'),
#   ('fishermen', 'bör'),
#   ('as', 'delta'),
#   ('well', 'i'),
#   ('as', 'denna'),
#   ('scientists.', 'kartläggning.')],
#  [('question', 'fråga'),
#   ('no', 'nr'),
#   ('33', '33'),
#   ('by', 'från'),
#   ('(h-0573/00):', '(h-0573/00):')],
#  [('this', 'detta'),
#   ('is', 'är'),
#   ('a', 'en'),
#   ('false', 'falsk'),
#   ('distinction.', 'skiljelinje.')],
#  [('clearly,', 'uppenbarligen'),
#   ('no', 'är'),
#   ('country', 'inget'),
#   ('or', 'land'),
#   ('sector', 'eller'),
#   ('is', 'område'),
#   ('risk-free.', 'riskfritt.')],
#  [('secondly,', 'för'),
#   ('the', 'det'),
#   ('situation', 'andra'),
#   ('calls', 'kräver'),
#   ('for', 'situationen'),
#   ('greater', 'större'),
#   ('transparency.', 'öppenhet.')],
#  [('our', 'utskottet'),
#   ('committee', 'kan'),
#   ('can', 'endast'),
#   ('make', 'komma'),
#   ('proposals', 'med'),
#   ('but', 'förslag,'),
#   ('not', 'inte'),
#   ('set', 'ge'),
#   ('parameters.', 'instruktioner.')],
#  [('we', 'vi'), ('have', 'har'), ('no', 'inget'), ('alternative.', 'val.')],
#  [('the', 'omröstningen'),
#   ('vote', 'kommer'),
#   ('will', 'att'),
#   ('take', 'äga'),
#   ('place', 'rum'),
#   ('today', 'i'),
#   ('at', 'dag'),
#   ('12', 'kl.'),
#   ('noon.', '12.00.')],
#  [('', '.')],
#  [('question', 'fråga'),
#   ('no', 'nr'),
#   ('50', '50'),
#   ('by', 'från'),
#   ('alexander', 'alexander'),
#   ('de', 'de'),
#   ('roo', 'roo'),
#   ('(h-0431/03):', '(h-0431/03):')],
#  [('let', 'låt'),
#   ('me', 'mig'),
#   ('add', 'tillägga'),
#   ('something', 'något'),
#   ('political.', 'politiskt.')],
#  [('-', '-'), ('wallis', 'betänkande:'), ('report', 'wallis')],
#  [('what', 'vad'),
#   ('can', 'kan'),
#   ('or', 'eller'),
#   ('what', 'bör'),
#   ('should', 'inledandet'),
#   ('initiating', 'av'),
#   ('this', 'en'),
#   ('dialogue', 'dialog'),
#   ('mean?', 'betyda?')],
#  [('11.', '11.')],
#  [('secondly,', 'för'),
#   ('there', 'det'),
#   ('is', 'andra'),
#   ('the', 'handlar'),
#   ('matter', 'det'),
#   ('of', 'om'),
#   ('patents.', 'patent.')],
#  [('let', 'låt'),
#   ('us', 'oss'),
#   ('stick', 'hålla'),
#   ('to', 'oss'),
#   ('the', 'till'),
#   ('facts.', 'fakta.')],
#  [('1.', '1.')],
#  [('', '.')],
#  [('we', 'vi'),
#   ('must', 'måste'),
#   ('know', 'veta'),
#   ('who', 'vilka'),
#   ('they', 'de'),
#   ('are.', 'är.')],
#  [('-', '-'), ('varvitsiotis', 'betänkande:'), ('report', 'varvitsiotis')]]

# %%
# Question A.4.1.8
# Generate frequency for the pair
en_sv_8 = en_sv_7.countByKey()
en_sv_8
# Out:
# defaultdict(int,
#             {('exactly', 'i'): 1,
#              ('the', 'jag'): 1344,
#              ('no.', 'nej.'): 112,
#              ('i', 'därför'): 94,
#              ('\xa0\xa0', '\xa0\xa0'): 1618,
#              ('madam', 'fru'): 108,
#              ('10.', '10.'): 128,
#              ('this', 'det'): 1307,
#              ('these', 'detta'): 107,
#              ('i', 'tack'): 34,
#              ('.', '.'): 1276,
#              ('question', 'fråga'): 1291,
#              ('', '.'): 2223,
#              ('that', 'sådan'): 4,
#              ('that', 'det'): 2357,
#              ('you', 'ni'): 441,
#              ('6.', '6.'): 180,
#              ('this', 'detta'): 2077,
#              ('we', 'vi'): 4171,
#              ('president.', 'talmannen.'): 57,
#              ('i', 'jag'): 4346,
#              ('there', 'det'): 1145,
#              ('that', 'detta'): 838,
#              ('waste', 'avfall'): 2,
#              ('nobody', 'ingen'): 33,
#              ('mr', 'herr'): 423,
#              ('that,', 'det'): 23,
#              ('technical', 'tekniska'): 3,
#              ('-', '-'): 403,
#              ('are', 'finns'): 314,
#              ('secondly,', 'för'): 70,
#              ('it', 'det'): 2313,
#              ('why?', 'varför?'): 361,
#              ('closure', 'avslutande'): 51,
#              ('perhaps', 'vi'): 11,
#              ('clarification', 'det'): 1,
#              ('what', 'vad'): 610,
#              ('the', 'omröstningen'): 1737,
#              ('two', 'två'): 52,
#              ('de', 'de'): 3,
#              ('the', 'debatten'): 1196,
#              ('generally', 'i'): 2,
#              ('the', 'yrkesfiskarna'): 1,
#              ('the', 'den'): 652,
#              ('bouwman.', 'bouwman.'): 1,
#              ('1.', '1.'): 438,
#              ('nothing', 'ingenting'): 34,
#              ('now', 'det'): 10,
#              ('17.', '17.'): 52,
#              ('forgive', 'förlåt'): 1,
#              ('(applause)', '(applåder)'): 2548,
#              ('what', 'vilken'): 78,
#              ('2.', '2.'): 438,
#              ('20.', '20.'): 38,
#              ('determination', 'medlemsstaternas'): 1,
#              ('vote', 'omröstning'): 114,
#              ('however,', 'men'): 191,
#              ('the', 'kanske'): 2,
#              ('europe', 'eu'): 79,
#              ('work', 'arbete'): 1,
#              ('first,', 'först'): 6,
#              ('our', 'vårt'): 66,
#              ('to', 'vi'): 4,
#              ('some', 'några'): 31,
#              ('i,', 'jag'): 7,
#              ('firstly,', 'för'): 55,
#              ('how', 'hur'): 312,
#              ('at', 'jag'): 1,
#              ('not', 'alla'): 5,
#              ('the', 'det'): 457,
#              ('russia', 'ryssland'): 21,
#              ('people', 'i'): 1,
#              ('never.', 'aldrig.'): 4,
#              ('welcome!', 'välkomna!'): 2,
#              ('in', 'i'): 249,
#              ('annex', 'bilaga'): 8,
#              ('different', 'olika'): 7,
#              ('so', 'hittills'): 5,
#              ('they', 'de'): 696,
#              ('for', 'för'): 89,
#              ('written', 'skriftliga'): 847,
#              ('introducing', 'införa'): 1,
#              ('this', 'i'): 34,
#              ('applause', 'applåder'): 429,
#              ('here', 'även'): 11,
#              ('information', 'informationen'): 3,
#              ('langen', 'betänkande:'): 1,
#              ('its', 'dess'): 23,
#              ('(laughter)', '(skratt)'): 64,
#              ('you', 'man'): 26,
#              ('so,', 'därför'): 1,
#              ('some', 'vi'): 1,
#              ('two', 'var'): 1,
#              ('children', 'barnen'): 6,
#              ('as', 'som'): 77,
#              ('decisions', 'beslut'): 87,
#              ('the', 'de'): 221,
#              ('let', 'låt'): 632,
#              ('thank', 'tack'): 425,
#              ('before', '-'): 31,
#              ('only', 'endast'): 27,
#              ('firstly', 'det'): 1,
#              ('but', 'men'): 472,
#              ('(loud', '(livliga'): 161,
#              ('how', 'vad'): 4,
#              ('votes', 'omröstning'): 161,
#              ('this', 'så'): 48,
#              ('winter', 'som'): 1,
#              ('there,', 'också'): 1,
#              ('the', 'eu'): 40,
#              ('we', 'men'): 23,
#              ('things', 'det'): 6,
#              ('hungary', 'ungern'): 4,
#              ('and', 'och'): 254,
#              ('the', 'erfarenheten'): 1,
#              ('it', 'den'): 345,
#              ('we', 'det'): 312,
#              ('with', 'tillsammans'): 1,
#              ('corrections', 'rättelser'): 76,
#              ('the', 'betänkandet'): 19,
#              ('the', 'kinas'): 1,
#              ('these', 'dessa'): 266,
#              ('those', 'dessa'): 31,
#              ('our', 'våra'): 69,
#              ('you', 'det'): 35,
#              ('mr', 'alexander'): 3,
#              ('naturally,', 'naturligtvis'): 15,
#              ('(loud', '(kraftiga'): 8,
#              ('(protests)', '(protester)'): 32,
#              ('that', 'debatten'): 18,
#              ('who', 'vilka'): 16,
#              ('trade', 'de'): 1,
#              ('we', 'detta'): 59,
#              ('we', 'här'): 22,
#              ('this', 'även'): 13,
#              ('when', 'när'): 44,
#              ('vehicles', 'fordon'): 2,
#              ('for', 'av'): 41,
#              ('violence', 'våldet'): 3,
#              ('monday/tuesday/wednesday:', 'måndag/tisdag/onsdag:'): 1,
#              ('he', 'han'): 238,
#              ('once', 'än'): 4,
#              ('8.', '8.'): 153,
#              ('the', 'politiska'): 1,
#              ('they', 'alla'): 2,
#              ('subject:', 'angående:'): 315,
#              ('one', 'ett'): 36,
#              ('parliament', 'parlamentet'): 105,
#              ('we', 'nu'): 38,
#              ('those', 'det'): 21,
#              ('the', 'nästa'): 157,
#              ('the', 'problemet'): 19,
#              ('which', 'vilken'): 16,
#              ('every', 'där'): 1,
#              ('is', 'är'): 272,
#              ('we', 'herr'): 4,
#              ('human', 'mänskliga'): 45,
#              ('such', 'en'): 25,
#              ('timing', 'valet'): 1,
#              ('with', 'med'): 31,
#              ('after', 'det'): 6,
#              ("dell'", 'betänkande'): 1,
#              ('the', 'min'): 5,
#              ('the', 'kommissionen'): 166,
#              ('small-scale', 'det'): 1,
#              ('many', 'många'): 88,
#              ('mr', 'sydafrika,'): 1,
#              ('these', 'den'): 2,
#              ('this', 'denna'): 323,
#              ('given', 'eftersom'): 1,
#              ('it', 'barnet'): 1,
#              ('some', 'en'): 19,
#              ('why', 'varför'): 316,
#              ('it', 'därför'): 21,
#              ('apart', 'har'): 1,
#              ('the', 'konstitutionen'): 6,
#              ('ukraine', 'ukraina'): 20,
#              ('ironically,', 'ironiskt'): 1,
#              ('we', 'enligt'): 2,
#              ('there', 'någon'): 1,
#              ('reports', 'rapporterna'): 1,
#              ('the', 'i'): 71,
#              ('it', 'detta'): 122,
#              ('we', 'därför'): 79,
#              ('undeclared', 'odeklarerat'): 1,
#              ('conditions', 'olika'): 1,
#              ('on', 'här'): 2,
#              ('europe', 'europa'): 139,
#              ('i', 'dessutom'): 1,
#              ('an', 'en'): 18,
#              ('thank', 'tack,'): 309,
#              ('may', 'må'): 7,
#              ('the', 'rådet'): 42,
#              ('the', 'wto'): 2,
#              ('formentera', 'formentera'): 1,
#              ('15.', '15.'): 66,
#              ('nonetheless,', 'trots'): 9,
#              ('on', 'på'): 25,
#              ('trade', 'även'): 1,
#              ('(nl)', '(nl)'): 25,
#              ('they', 'det'): 61,
#              ('there', 'inget'): 1,
#              ('it', 'föredraganden'): 1,
#              ('terrorism', 'terrorism'): 11,
#              ('one', 'en'): 71,
#              ('so', 'så'): 176,
#              ('the', 'the'): 11,
#              ('yes,', 'ja,'): 70,
#              ('27.', '27.'): 14,
#              ('but', 'låt'): 3,
#              ('13.', '13.'): 88,
#              ('membership', 'de'): 20,
#              ('ladies', 'mina'): 19,
#              ('accordingly,', 'jag'): 3,
#              ('in', 'jag'): 39,
#              ('great', 'stora'): 1,
#              ('perhaps', 'han'): 1,
#              ('7.', '7.'): 163,
#              ('hypocritical', 'hyckleri'): 1,
#              ('one', 'vår'): 1,
#              ('thank', 'jag'): 63,
#              ('21.', '21.'): 32,
#              ('therefore,', 'därför'): 79,
#              ('our', 'det'): 7,
#              ('this', 'också'): 4,
#              ('nor', 'inte'): 6,
#              ('in', 'enligt'): 34,
#              ('both', 'båda'): 50,
#              ('documents', 'inkomna'): 226,
#              ('possibly', 'den'): 1,
#              ("manufacturers'", 'tillverkarnas'): 1,
#              ('trade', 'handel'): 9,
#              ('pactio', 'pactio'): 23,
#              ('what', 'vilka'): 149,
#              ('(fr)', '(fr)'): 42,
#              ('forwarding', 'översändande'): 80,
#              ('then', 'det'): 3,
#              ('4.', '4.'): 247,
#              ('tomorrow', 'i'): 2,
#              ('well', 'bra'): 25,
#              ('menrad', 'betänkande:'): 1,
#              ('declaration', 'uppgifter'): 8,
#              ('mr', '(en)'): 51,
#              ('sem', 'sem'): 1,
#              ('23.', '23.'): 27,
#              ('monday', 'måndag'): 7,
#              ('on', 'om'): 25,
#              ('11.', '11.'): 112,
#              ('or', 'eller'): 32,
#              ('additionality', 'additionalitet'): 1,
#              ('nevertheless,', 'trots'): 4,
#              ('(laughter', '(skratt'): 34,
#              ('there', 'arbetstagarnas'): 1,
#              ('where', 'så'): 1,
#              ('naturally,', 'jag'): 3,
#              ('points', 'punkt'): 2,
#              ('questions', 'frågor'): 29,
#              ('somebody', 'någon'): 3,
#              ('discharge', 'ansvarsfrihet'): 8,
#              ('now', 'men'): 9,
#              ('mrs\xa0wallström', 'margot'): 1,
#              ('right', 'vad'): 1,
#              ('until', 'fram'): 1,
#              ('this', 'den'): 74,
#              ('demagogic?', 'demagogiskt?'): 1,
#              ('request', 'begäran'): 11,
#              ('as', 'utifrån'): 1,
#              ('a', 'en'): 148,
#              ('security', 'säkerhet'): 12,
#              ('enlargement', 'utvidgningen'): 20,
#              ('finally,', 'slutligen'): 52,
#              ('better', 'bättre'): 14,
#              ('obviously', 'naturligtvis'): 3,
#              ('however,', 'schmidt'): 1,
#              ('we', 'i'): 23,
#              ('we', 'om'): 3,
#              ('darwin', 'darwin'): 1,
#              ("turkey's", 'turkiets'): 3,
#              ('however,', 'men,'): 2,
#              ('petitions:', 'framställningar:'): 60,
#              ('literally,', 'det'): 1,
#              ('part', 'första'): 24,
#              ('9.', '9.'): 135,
#              ('each', 'varje'): 15,
#              ('we', 'resten'): 1,
#              ('take,', 'ett'): 1,
#              ('bangladesh', 'bangladesh'): 5,
#              ('so', 'låt'): 15,
#              ('constitutional', 'konstitutionella'): 1,
#              ('mr', 'andrews'): 1,
#              ('does', 'finns'): 5,
#              ('everything', 'allt'): 25,
#              ('no-one', 'det'): 2,
#              ('europeans', 'eu-medborgarna'): 1,
#              ('(de)', '(de)'): 47,
#              ('article', 'artikel'): 9,
#              ('transatlantic', 'transatlantiska'): 4,
#              ('removing', 'men'): 1,
#              ('solidarity', 'solidaritet'): 9,
#              ('council', 'rådets'): 16,
#              ('mr', 'desama'): 1,
#              ('mr', 'guy'): 3,
#              ('if', 'är'): 1,
#              ('there', 'jag'): 7,
#              ('my', 'min'): 194,
#              ('consequently,', 'följaktligen'): 14,
#              ('wednesday:', 'onsdagen:'): 18,
#              ('that', 'omröstningen'): 64,
#              ('however,', 'bahati-lagen'): 1,
#              ('2008', 'ansvarsfrihet'): 13,
#              ('alan', 'även'): 1,
#              ('therefore', 'därför'): 26,
#              ('(heckling)', '(häcklande)'): 41,
#              ('european', 'den'): 10,
#              ('however,', 'det'): 69,
#              ('harmonised', 'harmoniserade'): 4,
#              ('agenda', 'föredragningslista'): 145,
#              ('yet', 'hyckleriet'): 1,
#              ('protection', 'skydd'): 16,
#              ('it', 'adressen'): 1,
#              ('because', 'det'): 3,
#              ('hitherto,', 'hittills'): 2,
#              ('yet', 'jag'): 1,
#              ('however,', 'vi'): 56,
#              ('what', 'någonting'): 1,
#              ('three', 'tre'): 24,
#              ('the', 'till'): 5,
#              ('the', 'situationen'): 24,
#              ('these', 'det'): 99,
#              ('2010', '2010'): 2,
#              ('the', 'vi'): 29,
#              ('some', 'detta'): 1,
#              ('such', 'sådana'): 32,
#              ('there', 'informella'): 1,
#              ('regrettably,', 'tyvärr'): 2,
#              ('12.', '12.'): 103,
#              ('strengthening', 'förstärkning'): 2,
#              ('in', 'det'): 35,
#              ('just', 'bara'): 13,
#              ('first', 'för'): 32,
#              ('the', 'landet'): 8,
#              ('commissioner,', 'herr'): 27,
#              ('whether', 'huruvida'): 3,
#              ('preference', 'man'): 1,
#              ('europe', 'nu'): 1,
#              ('macro-financial', 'makroekonomiskt'): 11,
#              ('the', 'förordningen'): 5,
#              ('3.', '3.'): 403,
#              ('i', 'i'): 18,
#              ('5.', '5.'): 207,
#              ('case', 'rättegång'): 2,
#              ('animal', 'animaliska'): 1,
#              ('patenting', 'patentering'): 1,
#              ('she', 'hon'): 65,
#              ('as', 'kan'): 1,
#              ('which', 'vad'): 3,
#              ('openness', 'öppenhet'): 1,
#              ('[com(2002)', '[kom(2002)'): 1,
#              ('assignment', 'uppdrag'): 2,
#              ('that', 'jag'): 116,
#              ('its', 'årets'): 1,
#              ('what', 'vart'): 1,
#              ('even', 'till'): 9,
#              ('i,', 'alla'): 1,
#              ('mr\xa0zīle', 'roberts'): 1,
#              ('i', '.'): 13,
#              ('good', 'goda'): 8,
#              ('mrs', 'fru'): 32,
#              ('simplified', 'förenklat'): 18,
#              ('that', 'så'): 95,
#              ('that', 'för'): 4,
#              ('•', '•'): 2,
#              ('miguel', 'miguel'): 2,
#              ('ahead', 'vi'): 1,
#              ('at', 'åtminstone'): 4,
#              ('approval', 'justering'): 99,
#              ('for', 'jag'): 12,
#              ('it', 'i'): 10,
#              ('finally,', 'till'): 12,
#              ('that', 'denna'): 33,
#              ('furthermore,', 'dessutom'): 11,
#              ('the', 'sektorn'): 4,
#              ('in', 'överbevisa'): 1,
#              ('the', 'avtalets'): 1,
#              ('now', 'jag'): 4,
#              ('i', 'det'): 267,
#              ('no,', 'nej,'): 66,
#              ('no', 'inget'): 14,
#              ('thirdly,', 'det'): 2,
#              ('unfortunately,', 'tyvärr'): 79,
#              ('improved', 'förbättrade'): 1,
#              ('a', 'ett'): 89,
#              ('together', 'vi'): 1,
#              ('our', 'vår'): 105,
#              ('that', 'vi'): 10,
#              ('open', 'allmän'): 1,
#              ('thursday:', 'torsdagen:'): 7,
#              ('transparency', 'insyn'): 8,
#              ('new', 'vi'): 3,
#              ('today,', 'i'): 47,
#              ('congratulations,', 'gratulerar,'): 8,
#              ('this', 'bara'): 3,
#              ('part', 'del'): 51,
#              ('therefore,', 'vi'): 10,
#              ('dates', 'datum'): 91,
#              ('ec-eastern', 'interimsavtal'): 1,
#              ('all', 'allt'): 68,
#              ('the', 'unionen'): 13,
#              ('the', 'betänkande'): 7,
#              ('...', '...'): 12,
#              ('you', 'du'): 33,
#              ('we', 'de'): 7,
#              ('[pe-cons', '(pe-cons'): 3,
#              ('what', 'men'): 14,
#              ('szabolcs', 'szabolcs'): 2,
#              ('action', 'vi'): 1,
#              ('astrid', 'astrid'): 2,
#              ('anything', 'allt'): 10,
#              ('the', 'framtiden'): 3,
#              ('quite', 'varje'): 1,
#              ('have', 'har'): 46,
#              ('an', 'för'): 2,
#              ('i', 'låt'): 20,
#              ('succession', 'arv'): 2,
#              ('perhaps', 'kanske'): 51,
#              ('lifelong', 'livslångt'): 3,
#              ('transparency', 'öppenheten'): 2,
#              ('would', 'skulle'): 21,
#              ('very', 'mycket'): 17,
#              ('members', 'antal'): 1,
#              ('nobody.', 'ingen.'): 3,
#              ('sustainable', 'hållbar'): 6,
#              ('(parliament', '(parlamentet'): 162,
#              ('good', 'lycka'): 30,
#              ('are', 'tänker'): 1,
#              ('certain', 'vissa'): 11,
#              ('if', 'om'): 76,
#              ('allow', 'tillåt'): 8,
#              ('many', 'det'): 7,
#              ('oral', 'muntliga'): 76,
#              ('so', 'varför'): 7,
#              ('all', 'alla'): 61,
#              ('i', 'den'): 12,
#              ('be', 'var'): 15,
#              ('mr\xa0simpson', 'simpson'): 1,
#              ('(objections)', '(protester)'): 3,
#              ('(mixed', '(blandade'): 44,
#              ('sri', 'sri'): 3,
#              ('can', 'kan'): 83,
#              ('so,', 'låt'): 5,
#              ('welcome,', 'välkommen'): 1,
#              ('doing', 'att'): 1,
#              ('(applause', '(applåder'): 31,
#              ('croatia', 'kroatien'): 5,
#              ('the', 'länderna'): 3,
#              ('farmers', 'jordbrukarna'): 5,
#              ('also,', 'dessutom'): 1,
#              ('the', 'förändringarna'): 1,
#              ('case', 'per'): 1,
#              ('(interruption', '(avbrott'): 6,
#              ('please', 'tro'): 1,
#              ('mrs', 'jag'): 4,
#              ('after', 'därefter'): 3,
#              ('thus,', 'vi'): 2,
#              ('interest', 'räntan'): 1,
#              ('space', 'världsrymden'): 2,
#              ('someone', 'någon'): 9,
#              ('mrs', 'irena'): 1,
#              ('safety', 'säkerheten'): 6,
#              ("alzheimer's", 'alzheimers'): 1,
#              ('financial', 'ekonomiska'): 1,
#              ('(standing', '(stående'): 12,
#              ('22.', '22.'): 30,
#              ('demonstrations', 'demonstrationer'): 1,
#              ('we', 'sedan'): 3,
#              ('(bg)', '-'): 5,
#              ('', 'jugoslavien.'): 2,
#              ('this,', 'detta'): 26,
#              ('we', 'den'): 23,
#              ('milk', 'mjölk'): 2,
#              ('vehicle', 'utsläppen'): 1,
#              ('i', 'vad'): 4,
#              ('i', 'framför'): 1,
#              ('animals', 'djurtransporter'): 1,
#              ('preparation', 'förberedelser'): 3,
#              ('the', 'normen'): 1,
#              ('so,', 'vad'): 3,
#              ('the', 'man'): 13,
#              ('towards', 'i'): 1,
#              ('may', 'jag'): 5,
#              ('when', 'där'): 1,
#              ('what', 'det'): 87,
#              ('portugal', 'i'): 1,
#              ('when', 'i'): 1,
#              ('it', 'man'): 16,
#              ('second,', 'det'): 1,
#              ('(sustained', '(ihållande'): 32,
#              ('it', 'kina'): 2,
#              ('yet', 'men'): 21,
#              ('personally,', 'personligen'): 14,
#              ('thank', 'oändligt'): 8,
#              ('poor', 'användningen'): 1,
#              ('nor', 'det'): 5,
#              ('the', 'allmänheten'): 5,
#              ('illegals', 'illegala'): 1,
#              ('i', 'och'): 8,
#              ('eu-russia', 'toppmöte'): 1,
#              ('culture', 'programmet'): 5,
#              ('think', 'tänk'): 12,
#              ('section', 'avsnitt'): 28,
#              ('(1)', '(1)'): 89,
#              ('since', 'sedan'): 13,
#              ('racism,', 'rasism,'): 1,
#              ('therefore,', 'så,'): 2,
#              ('welcome', 'välkomsthälsning'): 167,
#              ('the', 'en'): 15,
#              ('sexual', 'sexuella'): 1,
#              ('–', '–'): 6,
#              ('water', 'vatten'): 8,
#              ('under', 'under'): 11,
#              ('clearly,', 'detta'): 4,
#              ('the', 'lagar'): 1,
#              ('a', 'det'): 54,
#              ('.', 'skriftligt.'): 1,
#              ('so', 'detta'): 13,
#              ('in', 'sammanfattningsvis'): 8,
#              ('mr', 'ledamot'): 1,
#              ('.', ''): 81,
#              ('the', 'när'): 4,
#              ('nature', 'naturen'): 3,
#              ('lapsed', 'bortfallna'): 46,
#              ('knowledge', 'kunskap'): 2,
#              ('(15572/2010', '(15572/2010'): 1,
#              ('essentially,', 'han'): 1,
#              ('advanced', 'high'): 1,
#              ('his', 'hans'): 30,
#              ('unfortunately,', 'dessvärre'): 6,
#              ('just', 'titta'): 3,
#              ('other', 'andra'): 23,
#              ('it', 'vi'): 19,
#              ('one', 'man'): 12,
#              ('hulthén', 'betänkande:'): 1,
#              ('a', 'till'): 2,
#              ('progress', 'det'): 5,
#              ('the', 'avsaknaden'): 1,
#              ('2008', 'nu'): 1,
#              ('the', 'regeringen'): 2,
#              ('8', '8'): 1,
#              ('it', 'skatten'): 1,
#              ('here', 'här'): 34,
#              ('the', 'alla'): 3,
#              ('the', 'föredraganden'): 19,
#              ('sustainable', 'en'): 1,
#              ('child', 'barnarbete'): 2,
#              ('several', 'flera'): 16,
#              ('cash', 'cash'): 1,
#              ('telecommunications', 'telekommunikationer'): 1,
#              ('multilateral', 'multilateralt'): 2,
#              ('prime', 'premiärminister'): 1,
#              ('where', 'var'): 90,
#              ('25.', '25.'): 21,
#              ('2007', 'ansvarsfrihet'): 9,
#              ('fishermen', 'yrkesfiskare'): 1,
#              ('more', 'mer'): 25,
#              ('probably', 'troligtvis'): 2,
#              ('much', 'mycket'): 7,
#              ('agenda', 'arbetsplan'): 26,
#              ('perhaps', 'ni'): 7,
#              ('principle', 'princip'): 2,
#              ('my', 'men'): 2,
#              ('we', 'tillsammans'): 1,
#              ('it', 'de'): 15,
#              ('proposals', 'förslagen'): 2,
#              ('the', 'samtidigt'): 1,
#              ('(commons', '(commons'): 2,
#              ('second,', 'för'): 4,
#              ('in', 'ur'): 2,
#              ('written', 'skriftlig'): 79,
#              ('this', 'situationen'): 4,
#              ('in', 'vi'): 38,
#              ('classification', 'gemensam'): 1,
#              ('eight', 'där'): 1,
#              ('ouzký', 'betänkande:'): 1,
#              ('so', 'hur'): 6,
#              ('guarantees', 'garantierna'): 1,
#              ('the', 'skillnaderna'): 1,
#              ('the', 'frågan'): 52,
#              ('unfortunately', 'tyvärr'): 20,
#              ('i', 'en'): 3,
#              ('syria', 'syrien'): 5,
#              ('mechtild', 'mechtild'): 2,
#              ('potential', 'en'): 1,
#              ('(mr', '(ignasi'): 1,
#              ('please,', 'vill'): 1,
#              ('cameroon', 'kamerun'): 2,
#              ('data', 'dataskydd'): 1,
#              ('technically,', 'tekniskt'): 1,
#              ('communication', 'meddelande'): 30,
#              ('funding', 'finansieringen'): 4,
#              ('xenophobia', 'xenofobin'): 1,
#              ('some', 'det'): 3,
#              ('of', 'det'): 16,
#              ('unemployment', 'arbetslösheten'): 14,
#              ('hence', 'därför'): 35,
#              ('fantastic.', 'fantastiskt.'): 1,
#              ('let', 'vi'): 37,
#              ('13', '13'): 3,
#              ('we', 'rådet'): 1,
#              ('lastly,', 'slutligen'): 15,
#              ('mr', 'ordet'): 6,
#              ('the', 'who'): 1,
#              ('that', 'redan'): 2,
#              ('there', 'detta'): 14,
#              ('so', 'även'): 1,
#              ('ireland', 'irland'): 9,
#              ('in', 'skriftlig.'): 41,
#              ('(the', '(talmannen'): 49,
#              ('military', 'där'): 1,
#              ('eu-us', 'luftfartsavtal'): 2,
#              ('french', 'franska'): 2,
#              ('we', 'varför'): 1,
#              ('her', 'hon'): 1,
#              ('ecofin', 'ekofin'): 1,
#              ('external', 'extern'): 1,
#              ('thank', '(en)'): 22,
#              ('i', 'skriftlig.'): 6,
#              ('the', 'eu:'): 2,
#              ('45.', '45.'): 1,
#              ('it', 'så'): 11,
#              ('by', 'av'): 4,
#              ('jewish', 'judiska'): 2,
#              ('compromise', 'kompromiss'): 1,
#              ('the', 'samma'): 27,
#              ('illegal', 'olaglig'): 1,
#              ('and,', 'och'): 6,
#              ('this', 'kolleger!'): 2,
#              ('the', 'jugoslavien.'): 1,
#              ('patten,', 'patten,'): 2,
#              ('', 'bra.'): 1,
#              ('another', 'ett'): 12,
#              ('it', 'konferensen'): 1,
#              ('myanmar', 'myanmar'): 3,
#              ('attacks', 'attacker'): 1,
#              ('no', 'inga'): 46,
#              ('in', 'en'): 1,
#              ('israel', 'israel'): 5,
#              ('will', 'kommer'): 65,
#              ('first,', 'först,'): 1,
#              ('the', 'med'): 6,
#              ('yes', 'ja'): 24,
#              ('on', 'vi'): 9,
#              ('investment', 'reglerna'): 1,
#              ('that', 'frågestunden'): 54,
#              ('human', 'de'): 5,
#              ('i', '(en)'): 22,
#              ('but', 'men,'): 6,
#              ('°', '°'): 6,
#              ('the', 'meningen'): 1,
#              ('freedom', 'frihet'): 1,
#              ('however,', 'jag'): 44,
#              ('thus,', 'därför'): 4,
#              ('some', 'för'): 2,
#              ('first,', 'det'): 2,
#              ("europe's", 'europas'): 13,
#              ('currently,', 'hela'): 1,
#              ('so', 'saker'): 1,
#              ('14.', '14.'): 77,
#              ('these', 'båda'): 1,
#              ('the', 'punkten'): 20,
#              ('urgent', 'brådskande'): 6,
#              ('kellett-bowman', 'betänkande:'): 1,
#              ('galileo', 'galileo'): 7,
#              ('internal', 'den'): 3,
#              ('in', 'avslutningsvis'): 1,
#              ('let', 'jag'): 45,
#              ("women's", 'kvinnors'): 11,
#              ('like', 'liksom'): 4,
#              ('there', 'i'): 8,
#              ('first', 'första'): 12,
#              ('what,', 'vilka'): 2,
#              ('political', 'politiska'): 6,
#              ('c5-0290/2001', 'c5-0290/2001'): 1,
#              ('that', 'genomförbart'): 1,
#              ('do', 'vet'): 8,
#              ('hoxha', 'hoxha'): 2,
#              ('joint', 'gemensam'): 6,
#              ('(parliament', '(det'): 7,
#              ('most', 'största'): 1,
#              ('because', 'säkerheten'): 1,
#              ('of', 'naturligtvis'): 27,
#              ('step', 'träd'): 1,
#              ('now', 'nu'): 116,
#              ('too', 'det'): 3,
#              ('congratulations,', 'grattis,'): 1,
#              ('neither', 'ingendera'): 2,
#              ('big?', 'stor?'): 1,
#              ('we', 'låt'): 16,
#              ('colleagues!', 'kolleger!'): 1,
#              ('position', 'bilaga'): 1,
#              ('nikiforos', 'nikiforos'): 1,
#              ('do', 'den'): 1,
#              ('well,', 'nåväl,'): 6,
#              ('tuesday:', 'tisdag:'): 15,
#              ('again,', 'återigen'): 4,
#              ('so', 'dessa'): 2,
#              ('climate', 'klimatförändringarna'): 3,
#              ('electric', 'eldrivna'): 3,
#              ('and', 'men'): 4,
#              ('the', 'västeuropeiska'): 1,
#              ('will', 'skall'): 4,
#              ('mr', 'sarlis'): 1,
#              ('has', 'har'): 32,
#              ('at', 'kanske'): 1,
#              ('37.', '37.'): 3,
#              ('gaza', 'gaza'): 4,
#              ('please', 'kan'): 1,
#              ('there', 'sedan'): 10,
#              ('selection', 'urval,'): 1,
#              ('we', 'man'): 34,
#              ('in', 'med'): 23,
#              ('in', 'för'): 13,
#              ('the', 'europeiska'): 67,
#              ('however,', 'slovakien'): 1,
#              ('agenda', 'agenda'): 8,
#              ('building', 'byggandet'): 1,
#              ('the', 'målet'): 3,
#              ('the', 'sammanträdet'): 3,
#              ('probably', 'förmodligen'): 1,
#              ('censorship?', 'censur?'): 1,
#              ('what', 'hur'): 61,
#              ('otherwise,', 'annars'): 13,
#              ('now,', 'nu,'): 1,
#              ('however,', 'den'): 19,
#              ('european', 'europeiska'): 37,
#              ('2006', 'ansvarsfrihet'): 7,
#              ('anger,', 'ilska,'): 1,
#              ('london', 'london'): 1,
#              ('the', 'svaret'): 15,
#              ('censorship,', 'med'): 1,
#              ('that', 'men'): 19,
#              ('meanwhile,', 'under'): 5,
#              ('turkey', 'turkiet'): 29,
#              ('smoking', 'rökning'): 1,
#              ('this', 'parlamentet'): 8,
#              ('sport', 'idrotten'): 4,
#              ('then', 'vad'): 1,
#              ('today’s', 'dagens'): 2,
#              ('eurodac', 'eurodac'): 2,
#              ('aids', 'aids'): 5,
#              ('rodi', 'rodi'): 2,
#              ('various', 'flera'): 3,
#              ('this', 'vi'): 26,
#              ('the', 'pengarna'): 3,
#              ('european', 'det'): 6,
#              ('(3)', '(3)'): 11,
#              ('uzbekistan', 'uzbekistan'): 5,
#              ('their', 'deras'): 57,
#              ('solidarity', 'ett'): 1,
#              ('your', 'ert'): 25,
#              ('tibet', 'tibet'): 8,
#              ('they', 'kommissionens'): 1,
#              ('', 'portugal.'): 1,
#              ('subsidiarity', 'subsidiaritetsprincipen'): 3,
#              ('consequently,', 'min'): 1,
#              ('two', 'det'): 12,
#              ('protectionism', 'protektionism'): 2,
#              ('2009', 'ansvarsfrihet'): 7,
#              ('my', 'för'): 2,
#              ('very', 'väldigt'): 2,
#              ('33.', '33.'): 9,
#              ('whose', 'vem'): 1,
#              ('industrial', 'en'): 2,
#              ('france', 'frankrike'): 14,
#              ('will', 'skulle'): 3,
#              ('the', 'institutionerna'): 1,
#              ('not', 'inte'): 48,
#              ('no!', 'nej!'): 50,
#              ('no.', 'nej!'): 7,
#              ('briefly,', 'dessa'): 1,
#              ('(hu)', '(hu)'): 13,
#              ('agriculture,', 'jordbruket'): 1,
#              ('remembrance', 'hågkomsten'): 1,
#              ('stefan', 'stefan'): 1,
#              ('while', 'medan'): 2,
#              ('clearly,', 'här'): 1,
#              ('the', 'ministern'): 1,
#              ('do', 'anser'): 8,
#              ('too', 'alltför'): 6,
#              ('they', 'man'): 12,
#              ('current', 'de'): 2,
#              ('impact', 'effekten'): 2,
#              ('we', 'även'): 10,
#              ('ideas', 'då'): 1,
#              ('worse', 'och'): 2,
#              ('he', 'det'): 13,
#              ('firstly', 'den'): 1,
#              ('much', 'det'): 9,
#              ('again,', 'återigen,'): 2,
#              ('half', 'hälften'): 3,
#              ('people', 'det'): 2,
#              ('the', 'siffrorna'): 18,
#              ('absolutely', 'absolut'): 14,
#              ('resolution', 'resolutionen'): 1,
#              ('everyone', 'alla'): 40,
#              ('external', 'ibland'): 1,
#              ('my', 'mitt'): 41,
#              ('[com(2000)', '(kom(2000)'): 14,
#              ('the', 'folket'): 3,
#              ('arrests,', 'arresteringarna,'): 1,
#              ('point', 'punkt'): 8,
#              ('in', '\xa0\xa0'): 1,
#              ('this', 'därmed'): 6,
#              ('combating', 'bekämpning'): 4,
#              ('putin', 'putin'): 2,
#              ('you,', 'ni'): 3,
#              ('(the', '(arbetsplanen'): 3,
#              ('advanced', 'läkemedel'): 2,
#              ('what', 'vilket'): 54,
#              ('well', 'rätt'): 6,
#              ('is', 'herr'): 1,
#              ('these', 'de'): 24,
#              ('they', 'dessa'): 21,
#              ('i', 'vi'): 3,
#              ('in', 'här'): 5,
#              ('the', 'sanningen'): 8,
#              ('we', 'europeiseringen'): 1,
#              ('we', 'hos'): 1,
#              ('uclaf', 'uclaf'): 3,
#              ('as', 'att'): 2,
#              ('access', 'tillgång'): 4,
#              ('today,', 'nu'): 2,
#              ('clearly,', 'det'): 7,
#              ('mr', 'jag'): 19,
#              ('for', 'det'): 15,
#              ('mrs', 'ainardi'): 1,
#              ('times', 'tiderna'): 8,
#              ('mrs', 'dagmar'): 1,
#              ('38.', '38.'): 3,
#              ('women', 'kvinnor'): 21,
#              ('the', 'nervositeten'): 1,
#              ('finland', 'finland'): 3,
#              ('mr', 'markus'): 1,
#              ('cancer', 'cancer'): 1,
#              ('fine!', 'visst!'): 1,
#              ('on', 'vid'): 1,
#              ('yet', 'vi'): 4,
#              ('problems', 'det'): 2,
#              ('however,', 'nu'): 3,
#              ('as', 'nederländare'): 1,
#              ('as', 'det'): 5,
#              ('you', 'herr'): 7,
#              ('farewell', 'farväl'): 1,
#              ('superb!', 'strålande!'): 2,
#              ('we', 'tack'): 1,
#              ('1997', 'ansvarsfrihet'): 2,
#              ('where', 'vilka'): 1,
#              ('the', 'stålkrisen'): 1,
#              ('who', 'vem'): 123,
#              ('cyprus', 'cypern'): 9,
#              ('agenda:', 'föredragningslista:'): 15,
#              ('lulling.', 'lulling.'): 1,
#              ('zimbabwe', 'zimbabwe'): 17,
#              ('that', '–'): 10,
#              ('so', 'jag'): 20,
#              ('health', 'hälsa'): 4,
#              ('reach', 'därför'): 1,
#              ('but', 'det'): 28,
#              ('this', 'därför'): 18,
#              ('(page', '(sid.'): 1,
#              ('yet', 'ändå'): 14,
#              ('', 'kommissionär\xa0bolkestein!'): 1,
#              ('i', 'ni'): 3,
#              ("karolina's", 'karolinas'): 1,
#              ('those', 'de'): 15,
#              ('for', 'mot'): 2,
#              ('finally,', 'avslutningsvis'): 16,
#              ('assistance', 'hjälpen'): 1,
#              ('your', 'er'): 29,
#              ('hunger', 'hungern'): 1,
#              ('now,', 'vad'): 4,
#              ('the', 'rådets'): 4,
#              ('mr', 'evans'): 2,
#              ("iran's", 'irans'): 3,
#              ('innovation', 'innovation'): 8,
#              ('but,', 'men'): 15,
#              ('civilians', 'den'): 1,
#              ('welcome,', 'välkommen,'): 5,
#              ('i', 'även'): 5,
#              ('malaysia', 'malaysia'): 6,
#              ('no', 'ingen'): 42,
#              ('experience', 'den'): 1,
#              ('skills', 'kunskaper'): 1,
#              ('several', 'många'): 3,
#              ('calendar', 'datum'): 11,
#              ('sustainable', 'vår'): 1,
#              ('necessary', 'nödvändigt,'): 1,
#              ('the', 'framför'): 2,
#              ('frankly,', 'uppriktigt'): 2,
#              ('accordingly,', 'därför'): 5,
#              ('international', 'denna'): 1,
#              ('pollution-related', 'miljörelaterade'): 1,
#              ('most', 'merparten'): 1,
#              ('topical', 'aktuell'): 27,
#              ('we', 'en'): 6,
#              ('in', 'detta'): 18,
#              ('this', 'förordningen'): 1,
#              ('people', 'folk'): 9,
#              ('others', 'andra'): 11,
#              ('nevertheless,', 'ändå'): 8,
#              ('open', 'öppen'): 2,
#              ('now', 'vi'): 3,
#              ('fortunately,', 'herr'): 1,
#              ('in', 'under'): 18,
#              ('indeed!', 'verkligen!'): 1,
#              ('under', 'varför'): 1,
#              ('poland', 'polen'): 4,
#              ('a', 'utbildning'): 1,
#              ('signature', 'undertecknande'): 5,
#              ('the', 'betänkandets'): 1,
#              ('in', 'även'): 4,
#              ('[com(2001)', '(kom(2001)'): 16,
#              ('eritrea', 'eritrea'): 1,
#              ('fundamentalism', 'fundamentalism'): 2,
#              ('you', 'den'): 1,
#              ('the', '–'): 5,
#              ('they', 'detta'): 10,
#              ('engagement', 'engagemang'): 1,
#              ('the', 'kostnaden'): 4,
#              ('europe’s', 'eu:s'): 1,
#              ('furthermore,', 'att'): 1,
#              ('if', 'i'): 8,
#              ('investment', 'det'): 1,
#              ("'european'", 'europeiskt'): 1,
#              ('mr', 'jörg'): 1,
#              ('the', 'kommissionsledamoten'): 4,
#              ('19.', '19.'): 46,
#              ('', 'författare.'): 2,
#              ('end', 'slut'): 7,
#              ('so', 'därför'): 25,
#              ('transparency', 'öppenhet'): 4,
#              ('it', 'sammanhållningspolitiken'): 1,
#              ("serbia's", 'serbiens'): 1,
#              ('sweden', 'sverige'): 7,
#              ('(interjection', '(protester'): 1,
#              ('now', 'så'): 2,
#              ('my', 'såvitt'): 1,
#              ('kyrgyzstan', 'kirgizistan'): 4,
#              ('that', 'och'): 7,
#              ('common', 'den'): 15,
#              ('are', 'ska'): 1,
#              ('poles', 'polacker'): 1,
#              ('which', 'vilka'): 25,
#              ('that', 'den'): 61,
#              ("parliament's", 'parlamentets'): 16,
#              ('16.', '16.'): 60,
#              ('baroness', 'catherine'): 2,
#              ('then', 'även'): 1,
#              ('madame', 'fru'): 1,
#              ('lastly,', 'avslutningsvis'): 3,
#              ('at', 'just'): 5,
#              ('five', 'det'): 1,
#              ('congratulations', 'gratulerar'): 1,
#              ('prime', 'herr'): 3,
#              ('agreed!', 'ok!'): 1,
#              ('sometimes', 'ibland'): 14,
#              ('the', 'samtliga'): 1,
#              ('the', 'godkännandet'): 1,
#              ('am', 'menar'): 1,
#              ('much', 'man'): 2,
#              ('neither', 'inte'): 2,
#              ('tashi', 'tashi'): 3,
#              ('however,', 'denna'): 8,
#              ('paragraph', 'i'): 3,
#              ('sanction', 'sanktion'): 1,
#              ('firstly,', 'problemet'): 1,
#              ('previous', 'i'): 1,
#              ('these', 'sådana'): 3,
#              ('efforts', 'ansträngningarna'): 1,
#              ('only', 'men'): 1,
#              ('politics,', 'politik,'): 1,
#              ('all', 'jämställdhetsaspekter'): 1,
#              ('sadly,', 'tyvärr'): 13,
#              ('public', 'de'): 2,
#              ('everyone', 'därför'): 1,
#              ('(2)', '(2)'): 27,
#              ('that,', 'detta'): 13,
#              ('protectionism.', 'protektionism.'): 1,
#              ('opposing', 'motsatta'): 1,
#              ('maybe', 'kanske'): 17,
#              ('thus,', 'därmed'): 1,
#              ('it', 'parlamentet'): 4,
#              ('draft', 'förslag'): 10,
#              ('on', 'av'): 1,
#              ('in', 'ni'): 1,
#              ('but', 'detta'): 8,
#              ('here', 'också'): 1,
#              ('judicial', 'straffrättsligt'): 2,
#              ('murder', 'mordet'): 1,
#              ('it', 'ordförandeskapet'): 1,
#              ('rains', 'det'): 1,
#              ...})

# %%
# Question A.4.1.9
# Printing top 20 frequently ocurring
print("Top 20 frquently occuring translation pair")
Counter(en_sv_8).most_common(20)
# Out:
# Top 20 frquently occuring translation pair
# [(('i', 'jag'), 4346),
#  (('we', 'vi'), 4171),
#  (('(applause)', '(applåder)'), 2548),
#  (('that', 'det'), 2357),
#  (('it', 'det'), 2313),
#  (('', '.'), 2223),
#  (('this', 'detta'), 2077),
#  (('the', 'omröstningen'), 1737),
#  (('\xa0\xa0', '\xa0\xa0'), 1618),
#  (('the', 'jag'), 1344),
#  (('this', 'det'), 1307),
#  (('question', 'fråga'), 1291),
#  (('.', '.'), 1276),
#  (('the', 'debatten'), 1196),
#  (('there', 'det'), 1145),
#  (('written', 'skriftliga'), 847),
#  (('that', 'detta'), 838),
#  (('they', 'de'), 696),
#  (('the', 'den'), 652),
#  (('let', 'låt'), 632)]

# %%
# release the cores for another application!
spark_context.stop()
